# %% [markdown]
# # Data Analytics and Classification Model for Failure Detection of Wind Turbine from IIoT Data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
from sklearn.svm import SVC

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 1. Read data

# %% [markdown]
# We have 3 data:
#
# * `scada_data.csv`: Contains >60 information (or status) of wind turbine components recorded by SCADA system
# * `fault_data.csv`: Contains wind turbine fault types (or modes)
# * `status_data.csv`: Contains description of status of wind turbine operational

# %%
scada_df = pd.read_csv('scada_data.csv')
scada_df['DateTime'] = pd.to_datetime(scada_df['DateTime'])
# scada_df.set_index('DateTime', inplace=True)

scada_df
# Out:
#                  DateTime        Time  Error  WEC: ava. windspeed  \
# 0     2014-05-01 00:00:00  1398920448      0                  6.9
# 1     2014-05-01 00:09:00  1398920960      0                  5.3
# 2     2014-05-01 00:20:00  1398921600      0                  5.0
# 3     2014-05-01 00:30:00  1398922240      0                  4.4
# 4     2014-05-01 00:39:00  1398922752      0                  5.7
# ...                   ...         ...    ...                  ...
# 49022 2015-04-08 23:20:00  1428553216      0                  3.9
# 49023 2015-04-08 23:30:00  1428553856      0                  3.9
# 49024 2015-04-08 23:39:00  1428554368      0                  4.2
# 49025 2015-04-08 23:50:00  1428555008      0                  4.1
# 49026 2015-04-09 00:00:00  1428555648      0                  4.8
#
#        WEC: max. windspeed  WEC: min. windspeed  WEC: ava. Rotation  \
# 0                      9.4                  2.9                0.00
# 1                      8.9                  1.6                0.00
# 2                      9.5                  1.4                0.00
# 3                      8.3                  1.3                0.00
# 4                      9.7                  1.2                0.00
# ...                    ...                  ...                 ...
# 49022                  5.5                  2.2                6.75
# 49023                  5.6                  2.9                6.64
# 49024                  6.7                  2.6                7.18
# 49025                  6.6                  2.7                7.02
# 49026                  6.0                  3.3                8.39
#
#        WEC: max. Rotation  WEC: min. Rotation  WEC: ava. Power  ...  \
# 0                    0.02                0.00                0  ...
# 1                    0.01                0.00                0  ...
# 2                    0.04                0.00                0  ...
# 3                    0.08                0.00                0  ...
# 4                    0.05                0.00                0  ...
# ...                   ...                 ...              ...  ...
# 49022                7.40                6.01              147  ...
# 49023                7.06                6.33              128  ...
# 49024                8.83                6.22              163  ...
# 49025                7.94                6.20              160  ...
# 49026                9.48                7.14              284  ...
#
#        Rectifier cabinet temp.  Yaw inverter cabinet temp.  \
# 0                           24                          20
# 1                           24                          20
# 2                           24                          20
# 3                           23                          21
# 4                           23                          21
# ...                        ...                         ...
# 49022                       33                          23
# 49023                       34                          23
# 49024                       34                          23
# 49025                       33                          23
# 49026                       33                          22
#
#        Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 0                              25             12           14
# 1                              25             12           14
# 2                              25             12           14
# 3                              25             12           14
# 4                              25             12           14
# ...                           ...            ...          ...
# 49022                          28              9           17
# 49023                          28              9           17
# 49024                          28              9           18
# 49025                          28              9           17
# 49026                          28              9           17
#
#        Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 0                         24                 34                  2501
# 1                         24                 34                  2501
# 2                         24                 34                  2501
# 3                         24                 34                  2501
# 4                         23                 34                  2501
# ...                      ...                ...                   ...
# 49022                     27                 35                  3050
# 49023                     27                 35                  3050
# 49024                     27                 34                  3050
# 49025                     27                 34                  3050
# 49026                     27                 34                  3050
#
#        Inverter averages  Inverter std dev
# 0              25.272728          1.103713
# 1              25.272728          1.103713
# 2              25.272728          1.103713
# 3              25.272728          1.103713
# 4              25.272728          1.103713
# ...                  ...               ...
# 49022          24.454546          3.474583
# 49023          24.454546          3.445683
# 49024          24.363636          3.413876
# 49025          24.000000          3.376389
# 49026          23.818182          3.250175
#
# [49027 rows x 66 columns]

# %%
status_df = pd.read_csv('status_data.csv')
status_df['DateTime'] = pd.to_datetime(status_df['DateTime'])
# status_df.set_index('DateTime', inplace=True)

status_df
# Out:
#                 DateTime  Main Status  Sub Status Full Status  \
# 0    2014-04-24 12:37:00            0           0        0:00
# 1    2014-04-25 19:27:00           71         104    71 : 104
# 2    2014-04-26 09:30:00            8           0        8:00
# 3    2014-04-26 10:05:00            8           0        8:00
# 4    2014-04-26 10:05:00            8           0        8:00
# ...                  ...          ...         ...         ...
# 1844 2015-04-27 07:26:00            0           0        0:00
# 1845 2015-04-28 22:14:00           26         373    26 : 373
# 1846 2015-04-28 22:14:00            0           2        0:02
# 1847 2015-04-28 22:17:00            0           1        0:01
# 1848 2015-04-28 22:18:00            0           0        0:00
#
#                                             Status Text  T  Service  FaultMsg  \
# 0                                  Turbine in operation  1    False     False
# 1     Insulation monitoring : Insulation fault Phase U2  6    False      True
# 2                                           Maintenance  6     True     False
# 3                                           Maintenance  6    False     False
# 4                                           Maintenance  6     True     False
# ...                                                 ... ..      ...       ...
# 1844                               Turbine in operation  1    False     False
# 1845  Malfunction fan-inverter : Other control board...  6    False     False
# 1846                                Turbine operational  1    False     False
# 1847                                   Turbine starting  1    False     False
# 1848                               Turbine in operation  1    False     False
#
#       Value0
# 0        7.4
# 1       20.5
# 2       17.1
# 3        8.7
# 4       10.6
# ...      ...
# 1844     7.0
# 1845     8.1
# 1846     9.5
# 1847    11.1
# 1848    11.5
#
# [1849 rows x 9 columns]

# %%
fault_df = pd.read_csv('fault_data.csv')
fault_df['DateTime'] = pd.to_datetime(fault_df['DateTime'])
# fault_df.set_index('DateTime', inplace=True)

fault_df
# Out:
#                DateTime          Time Fault
# 0   2014-05-14 14:39:44  1.400096e+09    GF
# 1   2014-05-14 14:50:24  1.400097e+09    GF
# 2   2014-05-14 14:58:56  1.400098e+09    GF
# 3   2014-05-14 15:09:36  1.400098e+09    GF
# 4   2014-05-14 15:20:16  1.400099e+09    GF
# ..                  ...           ...   ...
# 548 2015-01-14 23:00:48  1.421298e+09    AF
# 549 2015-01-14 23:09:20  1.421299e+09    AF
# 550 2015-01-15 22:50:08  1.421384e+09    AF
# 551 2015-01-15 23:00:48  1.421384e+09    AF
# 552 2015-01-15 23:09:20  1.421385e+09    AF
#
# [553 rows x 3 columns]

# %% [markdown]
# In the fault data, there are 5 types of faults, or fault modes:
#
# * gf: generator heating fault
# * mf: mains failure fault
# * ff: feeding fault
# * af: timeout warnmessage : malfunction aircooling
# * ef: excitation error : overvoltage DC-link

# %%
fault_df.Fault.unique()
# Out:
# array(['GF', 'MF', 'FF', 'AF', 'EF'], dtype=object)

# %% [markdown]
# # 2. Time series analysis

# %% [markdown]
# The 3 data have different time spans. The status data has the longest record timespan from January 2014 to December 2015. The shortest is SCADA data from April 2014 to April 2015. Therefore, when seeing the SCADA records, we can refer to status and fault data to see what happens on the turbine at certain timestamps.

# %%
# Plot time span of all data
t_scada = scada_df.DateTime
t_fault = fault_df.DateTime
t_status = status_df.DateTime

plt.figure(figsize=(10,4))
plt.plot(t_scada, np.full(len(scada_df), 1), label='scada data')
plt.plot(t_fault, np.full(len(fault_df), 2), label='fault data')
plt.plot(t_status, np.full(len(status_df), 3), label='status data')
plt.legend(loc='lower right')
plt.ylim(0,4)
# Out:
# (0.0, 4.0)

# %%
# Plot of max power from SCADA data
scada_df.plot(x='DateTime', y='WEC: max. Power', figsize=(15,4))
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %%
# Plot of max power on weekly resampled data
y = 'WEC: max. Power'
scada_df.resample('W', on='DateTime').mean().plot(y=y, figsize=(15,4))
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# There were times when power dropped, for example in October 2014, December 2014, and the most significant in January 2015.

# %%
# Plot of power production on monthly resampled data
y = 'WEC: Production kWh'
scada_df.resample('D', on='DateTime').mean().plot(y=y, figsize=(15,4))
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# The number of wind turbine faults significantly increases on October 2014.

# %%
# Plot of number of faults on monthly resampled data
fault_df.resample('M', on='DateTime').Fault.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %%
fault_df.resample('M', on='DateTime').Fault.value_counts()
# Out:
# DateTime    Fault
# 2014-05-31  GF        6
# 2014-06-30  AF       15
#             MF       14
#             FF        2
# 2014-07-31  AF       10
#             EF        8
#             FF        6
#             MF        2
# 2014-08-31  AF       28
#             EF        7
#             FF        6
# 2014-09-30  AF        3
# 2014-10-31  EF       93
#             FF       68
#             GF       11
#             MF        4
# 2014-11-30  EF       66
#             FF       25
# 2014-12-31  FF       49
# 2015-01-31  FF       98
#             GF       26
#             AF        6
# Name: Fault, dtype: int64

# %% [markdown]
# Let's plot the faults grouped by its fault modes. There are lots of EF events in October and November 2014, and lots of FF events from October 2014 - January 2015.

# %%
def line_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    month = label.month_name()[:3]
    if month == 'Jan':
        month += f'\n{label.year}'
    return month

# %%
c = ['red', 'orange', 'green', 'blue', 'violet']
fault_df.resample('M', on='DateTime').Fault.value_counts().unstack().plot.bar(stacked=True, width=0.8, figsize=(10,5), color=c, rot=45,
                                                                              title='Wind Turbine Faults', ylabel='Fault Counts')
# Out:
# <AxesSubplot:title={'center':'Wind Turbine Faults'}, xlabel='DateTime', ylabel='Fault Counts'>

# %% [markdown]
# # 3. Combine SCADA and faults data

# %% [markdown]
# We combine SCADA and fault data to pair each measurements with associated faults.

# %%
# Combine scada and fault data
df_combine = scada_df.merge(fault_df, on='Time', how='outer')
msno.matrix(df_combine)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are lots of NaNs, or unmatched SCADA timestamps with fault timestamps, simply because there are no faults happen at certain time. For these NaNs, we will replace with "NF".
#
# **NF is No Fault (normal condition)**

# %%
# Replace records that has no fault label (NaN) as 'NF' (no fault)
df_combine['Fault'] = df_combine['Fault'].replace(np.nan, 'NF')

df_combine
# Out:
#                DateTime_x        Time  Error  WEC: ava. windspeed  \
# 0     2014-05-01 00:00:00  1398920448      0                  6.9
# 1     2014-05-01 00:09:00  1398920960      0                  5.3
# 2     2014-05-01 00:20:00  1398921600      0                  5.0
# 3     2014-05-01 00:30:00  1398922240      0                  4.4
# 4     2014-05-01 00:39:00  1398922752      0                  5.7
# ...                   ...         ...    ...                  ...
# 49129 2015-04-08 23:20:00  1428553216      0                  3.9
# 49130 2015-04-08 23:30:00  1428553856      0                  3.9
# 49131 2015-04-08 23:39:00  1428554368      0                  4.2
# 49132 2015-04-08 23:50:00  1428555008      0                  4.1
# 49133 2015-04-09 00:00:00  1428555648      0                  4.8
#
#        WEC: max. windspeed  WEC: min. windspeed  WEC: ava. Rotation  \
# 0                      9.4                  2.9                0.00
# 1                      8.9                  1.6                0.00
# 2                      9.5                  1.4                0.00
# 3                      8.3                  1.3                0.00
# 4                      9.7                  1.2                0.00
# ...                    ...                  ...                 ...
# 49129                  5.5                  2.2                6.75
# 49130                  5.6                  2.9                6.64
# 49131                  6.7                  2.6                7.18
# 49132                  6.6                  2.7                7.02
# 49133                  6.0                  3.3                8.39
#
#        WEC: max. Rotation  WEC: min. Rotation  WEC: ava. Power  ...  \
# 0                    0.02                0.00                0  ...
# 1                    0.01                0.00                0  ...
# 2                    0.04                0.00                0  ...
# 3                    0.08                0.00                0  ...
# 4                    0.05                0.00                0  ...
# ...                   ...                 ...              ...  ...
# 49129                7.40                6.01              147  ...
# 49130                7.06                6.33              128  ...
# 49131                8.83                6.22              163  ...
# 49132                7.94                6.20              160  ...
# 49133                9.48                7.14              284  ...
#
#        Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 0                              25             12           14
# 1                              25             12           14
# 2                              25             12           14
# 3                              25             12           14
# 4                              25             12           14
# ...                           ...            ...          ...
# 49129                          28              9           17
# 49130                          28              9           17
# 49131                          28              9           18
# 49132                          28              9           17
# 49133                          28              9           17
#
#        Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 0                         24                 34                  2501
# 1                         24                 34                  2501
# 2                         24                 34                  2501
# 3                         24                 34                  2501
# 4                         23                 34                  2501
# ...                      ...                ...                   ...
# 49129                     27                 35                  3050
# 49130                     27                 35                  3050
# 49131                     27                 34                  3050
# 49132                     27                 34                  3050
# 49133                     27                 34                  3050
#
#        Inverter averages  Inverter std dev  DateTime_y  Fault
# 0              25.272728          1.103713         NaT     NF
# 1              25.272728          1.103713         NaT     NF
# 2              25.272728          1.103713         NaT     NF
# 3              25.272728          1.103713         NaT     NF
# 4              25.272728          1.103713         NaT     NF
# ...                  ...               ...         ...    ...
# 49129          24.454546          3.474583         NaT     NF
# 49130          24.454546          3.445683         NaT     NF
# 49131          24.363636          3.413876         NaT     NF
# 49132          24.000000          3.376389         NaT     NF
# 49133          23.818182          3.250175         NaT     NF
#
# [49134 rows x 68 columns]

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# Print the averages of SCADA values grouped by fault modes.

# %%
# Suppress scientific notations
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Group by fault and take average
df_summary = df_combine.groupby('Fault').mean().T
df_summary.tail(20)
# Out:
# Fault                            AF       EF       FF       GF       MF  \
# Blade C temp.               166.032  165.925  166.236  166.512  166.050
# Rotor temp. 1                55.565  100.368   66.071   34.140   52.300
# Rotor temp. 2                55.677   99.920   65.925   34.860   52.500
# Stator temp. 1               68.903  101.592   70.425   42.837   66.350
# Stator temp. 2               68.323  100.454   69.720   42.465   65.850
# Nacelle ambient temp. 1      15.629   14.500   11.016   12.116   14.800
# Nacelle ambient temp. 2      15.629   14.299   10.917   11.930   14.650
# Nacelle temp.                19.290   17.368   14.051   14.093   17.850
# Nacelle cabinet temp.        22.919   20.736   17.831   19.395   21.000
# Main carrier temp.           20.548   19.632   15.866   13.279   19.100
# Rectifier cabinet temp.      32.629   30.385   26.697   30.767   30.000
# Yaw inverter cabinet temp.   27.694   27.322   22.614   21.140   25.900
# Fan inverter cabinet temp.   32.032   29.948   26.323   24.860   30.050
# Ambient temp.                16.758   14.937   11.378   12.581   16.750
# Tower temp.                  28.129   28.891   21.638   16.349   27.150
# Control cabinet temp.        36.516   38.833   31.551   24.884   35.200
# Transformer temp.            46.903   64.121   51.063   30.233   45.250
# RTU: ava. Setpoint 1       3042.194 3049.425 3047.480 2973.395 2940.200
# Inverter averages            31.812   34.222   30.144   22.973   30.345
# Inverter std dev              1.439    1.617    1.639    1.141    1.456
#
# Fault                            NF
# Blade C temp.               165.640
# Rotor temp. 1                52.517
# Rotor temp. 2                52.614
# Stator temp. 1               60.702
# Stator temp. 2               60.204
# Nacelle ambient temp. 1      12.515
# Nacelle ambient temp. 2      12.435
# Nacelle temp.                16.339
# Nacelle cabinet temp.        19.852
# Main carrier temp.           16.551
# Rectifier cabinet temp.      30.354
# Yaw inverter cabinet temp.   24.325
# Fan inverter cabinet temp.   28.815
# Ambient temp.                13.386
# Tower temp.                  23.115
# Control cabinet temp.        31.758
# Transformer temp.            43.933
# RTU: ava. Setpoint 1       2988.201
# Inverter averages            27.807
# Inverter std dev              1.858

# %% [markdown]
# Seeing the averages above, we could identify the anomalous behavior of Fault Modes:
#
# * WF has lower ava, min, max active reactive power than No Fault (NF)
# * EF has higher ava, min, max active reactive power than No Fault (NF)
# * GF has ZERO ava, min, max active reactive power
# * FF and MF have higher nacelle cable twisting than NF
# * AF and GF have negative nacelle cable twisting
# * AF and MF have lower production
# * All faults have higher blade angle, the highest is FF
# * GF in general has the lowest temperature in ALL components (cabinet temp, T spinner, T front bearing, ..., T transformer)
# * While other faults (FF, AF, MF, EF) have higher temperature
# * EF temperature is highest in cabinet, pitch, rotor, stator, ambient, control, tower, and transformer
# * AF temperature is highest in spinner, front bearing, rare bearing, nacelle, main carrier, rectifier, yaw, and fan inverter

# %% [markdown]
# The boxplots of temperatures (at spinner, bearing, nacelle, and fan inverter) shows that during GF, the temperatures are anomalously lower than normal condition. However, temperatures are higher than normal during AF and EF.

# %%
# Boxplots of temperature
f, axes = plt.subplots(nrows=2, ncols=2,figsize=(10,8))

sns.boxplot(x='Fault', y='Spinner temp.', data=df_combine, ax=axes[0][0])
axes[0][0].set_title('Spinner Temperature')
sns.boxplot(x='Fault', y='Rear bearing temp.', data=df_combine, ax=axes[0][1])
axes[0][1].set_title('Rear Bearing Temperature')
sns.boxplot(x='Fault', y='Nacelle temp.', data=df_combine, ax=axes[1][0])
axes[1][0].set_title('Nacelle Temperature')
sns.boxplot(x='Fault', y='Fan inverter cabinet temp.', data=df_combine, ax=axes[1][1])
axes[1][1].set_title('Fan Inverter Temperature')

plt.tight_layout()

# %% [markdown]
# Boxplot of reactive power (power from the generator?) shows the power during EF is anomalously high, while the power during MF is lower than normal condition.

# %%
sns.catplot(data=df_combine, x='Fault', y='WEC: ava. reactive Power', kind='box')

# %% [markdown]
# The boxplot of nacelle position and cable twisting shows that during AF, nacelle position is negative (up to -500) while during MF, FF, and EF, nacelle position is positive (up to +500).

# %%
sns.catplot(data=df_combine, x='Fault', y='WEC: ava. Nacel position including cable twisting', kind='box')

# %% [markdown]
# The boxplot of operating hours shows that during MF and AF, the operating hours are shorter than normal condition. However, during FF, the operating hours are longer than normally are.

# %%
sns.catplot(data=df_combine, x='Fault', y='WEC: Operating Hours', kind='box')

# %% [markdown]
# # 5. Data preparation for ML

# %% [markdown]
# There are far more records of NF (normal condition) than faulty records - imbalanced dataset. We will sample the No Fault dataframe and pick only 300 records.

# %%
df_combine.Fault.value_counts()
# Out:
# NF    48581
# FF      254
# EF      174
# AF       62
# GF       43
# MF       20
# Name: Fault, dtype: int64

# %%
# No Fault mode data
df_nf = df_combine[df_combine.Fault=='NF'].sample(300, random_state=42)

df_nf
# Out:
#                DateTime_x        Time  Error  WEC: ava. windspeed  \
# 7340  2014-06-21 19:29:00  1403396992      0                3.500
# 949   2014-05-07 16:39:00  1399498752      0                5.300
# 37369 2015-01-17 00:00:00  1421474432      0                9.200
# 15200 2014-08-15 07:30:00  1408105856      0                7.200
# 42798 2015-02-23 22:30:00  1424752256      0               14.900
# ...                   ...         ...    ...                  ...
# 6298  2014-06-14 13:50:00  1402771840      0                2.200
# 22374 2014-10-04 01:38:00  1412404736      0                7.100
# 39742 2015-02-02 16:41:00  1422916864      0                2.100
# 34504 2014-12-28 02:40:00  1419756032      0                7.800
# 10632 2014-07-14 15:09:00  1405368576      0               11.300
#
#        WEC: max. windspeed  WEC: min. windspeed  WEC: ava. Rotation  \
# 7340                 4.600                2.400               6.370
# 949                 15.000                3.000               0.000
# 37369               10.800                8.100              13.480
# 15200                9.600                5.000              10.450
# 42798               20.900               11.200              14.690
# ...                    ...                  ...                 ...
# 6298                 4.300                0.400               4.600
# 22374                9.000                5.500              10.120
# 39742                2.600                1.700               5.050
# 34504                9.500                5.200              10.670
# 10632               15.200                6.100              13.560
#
#        WEC: max. Rotation  WEC: min. Rotation  WEC: ava. Power  ...  \
# 7340                6.640               6.160               87  ...
# 949                 0.000               0.000                0  ...
# 37369              13.950              12.920             2078  ...
# 15200              11.620               9.700              998  ...
# 42798              15.540              14.130             3060  ...
# ...                   ...                 ...              ...  ...
# 6298                5.120               4.150                1  ...
# 22374              10.770               9.500              875  ...
# 39742               5.320               4.940                6  ...
# 34504              11.720               9.360             1138  ...
# 10632              14.870              10.740             2638  ...
#
#        Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 7340                           40             20           26
# 949                            26             16           15
# 37369                          20              3           18
# 15200                          30             21           30
# 42798                          22              6           28
# ...                           ...            ...          ...
# 6298                           40             24           25
# 22374                          27             13           26
# 39742                          21              4            8
# 34504                          22              4           19
# 10632                          38             23           36
#
#        Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 7340                      36                 45                  3050
# 949                       24                 33                  2501
# 37369                     25                 40                  3050
# 15200                     37                 48                  3050
# 42798                     39                 67                  3050
# ...                      ...                ...                   ...
# 6298                      35                 45                  3050
# 22374                     34                 43                  3050
# 39742                     17                 27                  3050
# 34504                     27                 38                  3050
# 10632                     44                 64                  3050
#
#        Inverter averages  Inverter std dev  DateTime_y  Fault
# 7340              34.273             3.228         NaT     NF
# 949               24.455             0.934         NaT     NF
# 37369             19.091             1.446         NaT     NF
# 15200             30.545             1.036         NaT     NF
# 42798             28.273             1.902         NaT     NF
# ...                  ...               ...         ...    ...
# 6298              35.000             1.414         NaT     NF
# 22374             28.091             1.136         NaT     NF
# 39742             19.909             1.044         NaT     NF
# 34504             19.818             0.603         NaT     NF
# 10632             35.909             1.973         NaT     NF
#
# [300 rows x 68 columns]

# %%
# With fault mode data
df_f = df_combine[df_combine.Fault!='NF']

df_f
# Out:
#                DateTime_x        Time  Error  WEC: ava. windspeed  \
# 1945  2014-05-14 14:39:00  1400096384      0                5.700
# 1946  2014-05-14 14:50:00  1400097024      0                6.400
# 1947  2014-05-14 14:58:00  1400097536      0                5.600
# 1948  2014-05-14 15:09:00  1400098176      0                5.300
# 1949  2014-05-14 15:20:00  1400098816      0                5.100
# ...                   ...         ...    ...                  ...
# 37075 2015-01-14 23:00:00  1421298048      0               13.500
# 37076 2015-01-14 23:09:00  1421298560      0               15.500
# 37218 2015-01-15 22:50:00  1421383808      0                8.400
# 37219 2015-01-15 23:00:00  1421384448      0                8.100
# 37220 2015-01-15 23:09:00  1421384960      0                7.900
#
#        WEC: max. windspeed  WEC: min. windspeed  WEC: ava. Rotation  \
# 1945                 7.400                4.100               9.980
# 1946                 8.600                2.700               4.120
# 1947                 7.500                4.000               9.990
# 1948                 6.600                4.100               9.980
# 1949                 7.200                3.800               9.990
# ...                    ...                  ...                 ...
# 37075               22.000                7.700              14.690
# 37076               25.700                1.900               2.530
# 37218                9.700                6.800              12.790
# 37219                9.800                6.000              11.710
# 37220               11.600                1.900               1.400
#
#        WEC: max. Rotation  WEC: min. Rotation  WEC: ava. Power  ...  \
# 1945               10.230               9.720                0  ...
# 1946               10.710               0.700                0  ...
# 1947               10.200               9.800                0  ...
# 1948               10.170               9.790                0  ...
# 1949               10.170               9.800                0  ...
# ...                   ...                 ...              ...  ...
# 37075              15.190              13.830             2736  ...
# 37076              14.670               0.000               20  ...
# 37218              13.300              11.640             1667  ...
# 37219              13.270               9.990             1311  ...
# 37220              11.180               0.000               14  ...
#
#        Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 1945                           27             17           26
# 1946                           27             17           26
# 1947                           27             17           26
# 1948                           27             18           26
# 1949                           28             18           26
# ...                           ...            ...          ...
# 37075                          24              8           29
# 37076                          23              7           22
# 37218                          21              5           21
# 37219                          20              5           21
# 37220                          21              5           17
#
#        Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 1945                      35                 34                  2501
# 1946                      35                 34                  2501
# 1947                      35                 34                  2501
# 1948                      35                 34                  2501
# 1949                      35                 34                  2501
# ...                      ...                ...                   ...
# 37075                     35                 57                  3050
# 37076                     35                 57                  3050
# 37218                     28                 42                  3050
# 37219                     28                 42                  3050
# 37220                     28                 42                  3050
#
#        Inverter averages  Inverter std dev          DateTime_y  Fault
# 1945              25.818             0.603 2014-05-14 14:39:44     GF
# 1946              26.091             0.944 2014-05-14 14:50:24     GF
# 1947              26.455             0.820 2014-05-14 14:58:56     GF
# 1948              26.182             0.874 2014-05-14 15:09:36     GF
# 1949              26.182             0.982 2014-05-14 15:20:16     GF
# ...                  ...               ...                 ...    ...
# 37075             25.909             1.814 2015-01-14 23:00:48     AF
# 37076             28.182             1.834 2015-01-14 23:09:20     AF
# 37218             20.909             1.300 2015-01-15 22:50:08     AF
# 37219             20.909             1.300 2015-01-15 23:00:48     AF
# 37220             22.909             1.300 2015-01-15 23:09:20     AF
#
# [553 rows x 68 columns]

# %%
# Combine no fault and faulty dataframes

df_combine = pd.concat((df_nf, df_f), axis=0).reset_index(drop=True)

df_combine
# Out:
#              DateTime_x        Time  Error  WEC: ava. windspeed  \
# 0   2014-06-21 19:29:00  1403396992      0                3.500
# 1   2014-05-07 16:39:00  1399498752      0                5.300
# 2   2015-01-17 00:00:00  1421474432      0                9.200
# 3   2014-08-15 07:30:00  1408105856      0                7.200
# 4   2015-02-23 22:30:00  1424752256      0               14.900
# ..                  ...         ...    ...                  ...
# 848 2015-01-14 23:00:00  1421298048      0               13.500
# 849 2015-01-14 23:09:00  1421298560      0               15.500
# 850 2015-01-15 22:50:00  1421383808      0                8.400
# 851 2015-01-15 23:00:00  1421384448      0                8.100
# 852 2015-01-15 23:09:00  1421384960      0                7.900
#
#      WEC: max. windspeed  WEC: min. windspeed  WEC: ava. Rotation  \
# 0                  4.600                2.400               6.370
# 1                 15.000                3.000               0.000
# 2                 10.800                8.100              13.480
# 3                  9.600                5.000              10.450
# 4                 20.900               11.200              14.690
# ..                   ...                  ...                 ...
# 848               22.000                7.700              14.690
# 849               25.700                1.900               2.530
# 850                9.700                6.800              12.790
# 851                9.800                6.000              11.710
# 852               11.600                1.900               1.400
#
#      WEC: max. Rotation  WEC: min. Rotation  WEC: ava. Power  ...  \
# 0                 6.640               6.160               87  ...
# 1                 0.000               0.000                0  ...
# 2                13.950              12.920             2078  ...
# 3                11.620               9.700              998  ...
# 4                15.540              14.130             3060  ...
# ..                  ...                 ...              ...  ...
# 848              15.190              13.830             2736  ...
# 849              14.670               0.000               20  ...
# 850              13.300              11.640             1667  ...
# 851              13.270               9.990             1311  ...
# 852              11.180               0.000               14  ...
#
#      Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 0                            40             20           26
# 1                            26             16           15
# 2                            20              3           18
# 3                            30             21           30
# 4                            22              6           28
# ..                          ...            ...          ...
# 848                          24              8           29
# 849                          23              7           22
# 850                          21              5           21
# 851                          20              5           21
# 852                          21              5           17
#
#      Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 0                       36                 45                  3050
# 1                       24                 33                  2501
# 2                       25                 40                  3050
# 3                       37                 48                  3050
# 4                       39                 67                  3050
# ..                     ...                ...                   ...
# 848                     35                 57                  3050
# 849                     35                 57                  3050
# 850                     28                 42                  3050
# 851                     28                 42                  3050
# 852                     28                 42                  3050
#
#      Inverter averages  Inverter std dev          DateTime_y  Fault
# 0               34.273             3.228                 NaT     NF
# 1               24.455             0.934                 NaT     NF
# 2               19.091             1.446                 NaT     NF
# 3               30.545             1.036                 NaT     NF
# 4               28.273             1.902                 NaT     NF
# ..                 ...               ...                 ...    ...
# 848             25.909             1.814 2015-01-14 23:00:48     AF
# 849             28.182             1.834 2015-01-14 23:09:20     AF
# 850             20.909             1.300 2015-01-15 22:50:08     AF
# 851             20.909             1.300 2015-01-15 23:00:48     AF
# 852             22.909             1.300 2015-01-15 23:09:20     AF
#
# [853 rows x 68 columns]

# %% [markdown]
# Preparing for the training dataset, we **drop irrelevant features**. First we drop datetime, time, and error columns. Next, features that "de facto" are output of wind turbine, such as power from wind, operating hours, and kWh production, are dropped. Also, climatic variable such as wind speed are not useful.

# %%
# Drop irrelevant features (feature selection)
train_df = df_combine.drop(columns=['DateTime_x', 'Time', 'Error', 'WEC: ava. windspeed', 
                                    'WEC: ava. available P from wind',
                                    'WEC: ava. available P technical reasons',
                                    'WEC: ava. Available P force majeure reasons',
                                    'WEC: ava. Available P force external reasons',
                                    'WEC: max. windspeed', 'WEC: min. windspeed', 
                                    'WEC: Operating Hours', 'WEC: Production kWh',
                                    'WEC: Production minutes', 'DateTime_y'])

train_df
# Out:
#      WEC: ava. Rotation  WEC: max. Rotation  WEC: min. Rotation  \
# 0                 6.370               6.640               6.160
# 1                 0.000               0.000               0.000
# 2                13.480              13.950              12.920
# 3                10.450              11.620               9.700
# 4                14.690              15.540              14.130
# ..                  ...                 ...                 ...
# 848              14.690              15.190              13.830
# 849               2.530              14.670               0.000
# 850              12.790              13.300              11.640
# 851              11.710              13.270               9.990
# 852               1.400              11.180               0.000
#
#      WEC: ava. Power  WEC: max. Power  WEC: min. Power  \
# 0                 87              123               65
# 1                  0                0                0
# 2               2078             2533             1696
# 3                998             1491              710
# 4               3060             3114             2994
# ..               ...              ...              ...
# 848             2736             2798             2417
# 849               20             2746                0
# 850             1667             1914             1259
# 851             1311             1945              781
# 852               14             1097                0
#
#      WEC: ava. Nacel position including cable twisting  \
# 0                                                  171
# 1                                                  -52
# 2                                                  -66
# 3                                                 -376
# 4                                                  -68
# ..                                                 ...
# 848                                                -78
# 849                                                -76
# 850                                                -66
# 851                                                -53
# 852                                                -49
#
#      WEC: ava. reactive Power  WEC: max. reactive Power  \
# 0                          32                        32
# 1                           0                         0
# 2                         173                       204
# 3                          64                        79
# 4                         296                       299
# ..                        ...                       ...
# 848                       238                       243
# 849                         4                       241
# 850                       145                       170
# 851                       111                       155
# 852                         3                       110
#
#      WEC: min. reactive Power  ...  Yaw inverter cabinet temp.  \
# 0                          32  ...                          36
# 1                           0  ...                          22
# 2                         152  ...                          16
# 3                          55  ...                          24
# 4                         294  ...                          19
# ..                        ...  ...                         ...
# 848                       224  ...                          21
# 849                         0  ...                          21
# 850                       119  ...                          17
# 851                        77  ...                          16
# 852                         0  ...                          17
#
#      Fan inverter cabinet temp.  Ambient temp.  Tower temp.  \
# 0                            40             20           26
# 1                            26             16           15
# 2                            20              3           18
# 3                            30             21           30
# 4                            22              6           28
# ..                          ...            ...          ...
# 848                          24              8           29
# 849                          23              7           22
# 850                          21              5           21
# 851                          20              5           21
# 852                          21              5           17
#
#      Control cabinet temp.  Transformer temp.  RTU: ava. Setpoint 1  \
# 0                       36                 45                  3050
# 1                       24                 33                  2501
# 2                       25                 40                  3050
# 3                       37                 48                  3050
# 4                       39                 67                  3050
# ..                     ...                ...                   ...
# 848                     35                 57                  3050
# 849                     35                 57                  3050
# 850                     28                 42                  3050
# 851                     28                 42                  3050
# 852                     28                 42                  3050
#
#      Inverter averages  Inverter std dev  Fault
# 0               34.273             3.228     NF
# 1               24.455             0.934     NF
# 2               19.091             1.446     NF
# 3               30.545             1.036     NF
# 4               28.273             1.902     NF
# ..                 ...               ...    ...
# 848             25.909             1.814     AF
# 849             28.182             1.834     AF
# 850             20.909             1.300     AF
# 851             20.909             1.300     AF
# 852             22.909             1.300     AF
#
# [853 rows x 54 columns]

# %%
# Imbalanced fault modes
train_df.Fault.value_counts().plot.pie(title='Fault Modes')
# Out:
# <AxesSubplot:title={'center':'Fault Modes'}, ylabel='Fault'>

# %% [markdown]
# # 6. Machine learning - fault modes classification

# %% [markdown]
# We are going to build a predictive model to classify fault modes of wind turbine based on the information or status of wind turbine components (gear box, tower, nacelle, bearing, etc.) from SCADA system. This is a multiclass classification task.
#
# Because our training data is largely imbalanced for each fault modes, we use **SMOTE** (Synthetic Minority Oversampling Technique) to oversample the minority classes. The classifier that we use is **SVC** (Suppot Vector Machines). To avoid overfitting, we did **Stratified K-Fold** cross-validation with 5-folds. **Multiple scoring metrics** are used: accuracy, macro-averaged precision, macro recall, and macro F1 score.
#
# **NOTE.** During cross-validation, the train set will be divided into train set and validation set. Therefore, to ensure that the train set is balanced, the SMOTE should be put inside via **pipeline**. If outside, the score result will be unfair (see this [article](https://towardsdatascience.com/the-right-way-of-using-smote-with-cross-validation-92a8d09d00c7)).

# %%
# Feature and target
# X = df_combine.iloc[:,3:-2]
# y = df_combine.iloc[:,-1]
X = train_df.iloc[:,:-1]
y = train_df.iloc[:,-1]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Make pipeline of scaling, and classifier
pipe = make_pipeline(StandardScaler(), SVC(random_state=42, class_weight='balanced'))

# Define multiple scoring metrics
scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_macro': 'recall_macro',
           'f1_macro': 'f1_macro'}

# Stratified K-Fold 
stratkfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Return a dictionary of all scorings
cv_scores = cross_validate(pipe, X_train, y_train, cv=stratkfold, scoring=scoring)

# %%
# Print scoring results from dictionary
for metric_name, metric_value in cv_scores.items():
    mean = np.mean(metric_value)
    print(f'{metric_name}: {np.round(metric_value, 4)}, Mean: {np.round(mean, 4)}')
# Out:
# fit_time: [0.009 0.008 0.008 0.008 0.008], Mean: 0.0082
# score_time: [0.005 0.005 0.005 0.004 0.004], Mean: 0.0046
# test_acc: [0.7    0.6917 0.7059 0.6471 0.6975], Mean: 0.6884
# test_prec_macro: [0.6772 0.664  0.7253 0.6445 0.6574], Mean: 0.6737
# test_rec_macro: [0.7104 0.6925 0.7024 0.6911 0.6892], Mean: 0.6971
# test_f1_macro: [0.662  0.646  0.6756 0.6171 0.6506], Mean: 0.6503

# %% [markdown]
# **The precision, recall, and F1 score are 66%.**

# %%
# Fit pipeline to train set
pipe.fit(X_train, y_train)

# Predict on test set
y_pred = pipe.predict(X_test)

# %%
# Confusion matrix of test set
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# We can see 2 problematic (false predicted) classes here are FF and EF. There are 28 FF predicted as EF.

# %%
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AF       0.38      0.55      0.45        20
#           EF       0.59      1.00      0.75        57
#           FF       0.97      0.45      0.61        76
#           GF       0.91      1.00      0.95        10
#           MF       0.25      0.43      0.32         7
#           NF       0.78      0.66      0.72        86
#
#     accuracy                           0.67       256
#    macro avg       0.65      0.68      0.63       256
# weighted avg       0.75      0.67      0.67       256

# %% [markdown]
# # 7. Hyperparameter tuning

# %% [markdown]
# From our previous LightGBM model, we achieved 65% precision, recall, and F1, however we find 2 problematic classes being falsely predicted. We will improve our model with hyperparameter tuning. We will do grid search over **4 hyperparameters** and optimize the **F1 score** as our metric.

# %%
# Define parameter search grid

param_grid = {'svc__C': [1, 10, 100],
              'svc__degree': [2, 3],
              'svc__kernel': ['poly']}

# Grid search CV
grid = GridSearchCV(pipe, param_grid, scoring = 'f1_macro', cv = 10, verbose = 10)

# Fit grid on train set
grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV 1/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 1/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.542 total time=   0.0s
# [CV 2/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 2/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.699 total time=   0.0s
# [CV 3/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 3/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.561 total time=   0.0s
# [CV 4/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 4/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.520 total time=   0.0s
# [CV 5/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 5/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.681 total time=   0.0s
# [CV 6/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 6/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.692 total time=   0.0s
# [CV 7/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 7/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.659 total time=   0.0s
# [CV 8/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 8/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.563 total time=   0.0s
# [CV 9/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly..................
# [CV 9/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.483 total time=   0.0s
# [CV 10/10; 1/6] START svc__C=1, svc__degree=2, svc__kernel=poly.................
# [CV 10/10; 1/6] END svc__C=1, svc__degree=2, svc__kernel=poly;, score=0.526 total time=   0.0s
# [CV 1/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 1/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.522 total time=   0.0s
# [CV 2/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 2/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.691 total time=   0.0s
# [CV 3/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 3/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.527 total time=   0.0s
# [CV 4/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 4/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.529 total time=   0.0s
# [CV 5/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 5/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.682 total time=   0.0s
# [CV 6/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 6/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.642 total time=   0.0s
# [CV 7/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 7/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.724 total time=   0.0s
# [CV 8/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 8/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.577 total time=   0.0s
# [CV 9/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly..................
# [CV 9/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.488 total time=   0.0s
# [CV 10/10; 2/6] START svc__C=1, svc__degree=3, svc__kernel=poly.................
# [CV 10/10; 2/6] END svc__C=1, svc__degree=3, svc__kernel=poly;, score=0.610 total time=   0.0s
# [CV 1/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 1/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.490 total time=   0.0s
# [CV 2/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 2/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.591 total time=   0.0s
# [CV 3/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 3/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.564 total time=   0.0s
# [CV 4/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 4/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.579 total time=   0.0s
# [CV 5/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 5/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.716 total time=   0.0s
# [CV 6/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 6/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.728 total time=   0.0s
# [CV 7/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 7/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.670 total time=   0.0s
# [CV 8/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 8/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.618 total time=   0.0s
# [CV 9/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly.................
# [CV 9/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.536 total time=   0.0s
# [CV 10/10; 3/6] START svc__C=10, svc__degree=2, svc__kernel=poly................
# [CV 10/10; 3/6] END svc__C=10, svc__degree=2, svc__kernel=poly;, score=0.570 total time=   0.0s
# [CV 1/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 1/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.474 total time=   0.0s
# [CV 2/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 2/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.592 total time=   0.0s
# [CV 3/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 3/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.556 total time=   0.0s
# [CV 4/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 4/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.647 total time=   0.0s
# [CV 5/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 5/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.745 total time=   0.0s
# [CV 6/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 6/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.643 total time=   0.0s
# [CV 7/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 7/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.693 total time=   0.0s
# [CV 8/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 8/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.641 total time=   0.0s
# [CV 9/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly.................
# [CV 9/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.565 total time=   0.0s
# [CV 10/10; 4/6] START svc__C=10, svc__degree=3, svc__kernel=poly................
# [CV 10/10; 4/6] END svc__C=10, svc__degree=3, svc__kernel=poly;, score=0.585 total time=   0.0s
# [CV 1/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 1/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.525 total time=   0.0s
# [CV 2/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 2/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.632 total time=   0.0s
# [CV 3/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 3/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.533 total time=   0.0s
# [CV 4/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 4/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.594 total time=   0.0s
# [CV 5/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 5/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.726 total time=   0.0s
# [CV 6/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 6/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.710 total time=   0.0s
# [CV 7/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 7/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.671 total time=   0.0s
# [CV 8/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 8/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.634 total time=   0.0s
# [CV 9/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly................
# [CV 9/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.556 total time=   0.0s
# [CV 10/10; 5/6] START svc__C=100, svc__degree=2, svc__kernel=poly...............
# [CV 10/10; 5/6] END svc__C=100, svc__degree=2, svc__kernel=poly;, score=0.581 total time=   0.0s
# [CV 1/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 1/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.466 total time=   0.0s
# [CV 2/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 2/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.564 total time=   0.0s
# [CV 3/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 3/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.506 total time=   0.0s
# [CV 4/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 4/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.627 total time=   0.0s
# [CV 5/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 5/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.691 total time=   0.0s
# [CV 6/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 6/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.658 total time=   0.0s
# [CV 7/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 7/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.646 total time=   0.0s
# [CV 8/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 8/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.643 total time=   0.0s
# [CV 9/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly................
# [CV 9/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.531 total time=   0.0s
# [CV 10/10; 6/6] START svc__C=100, svc__degree=3, svc__kernel=poly...............
# [CV 10/10; 6/6] END svc__C=100, svc__degree=3, svc__kernel=poly;, score=0.490 total time=   0.0s
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=42))]),
#              param_grid={'svc__C': [1, 10, 100], 'svc__degree': [2, 3],
#                          'svc__kernel': ['poly']},
#              scoring='f1_macro', verbose=10)

# %% [markdown]
# We got **improvement to 70% F1-score** with the following tuned hyperparameters.

# %%
# Best model from tuning
print(grid.best_params_)
print(f'Average of Macro F1: {grid.best_score_}')
# Out:
# {'svc__C': 100, 'svc__degree': 2, 'svc__kernel': 'poly'}
# Average of Macro F1: 0.6161465146876706

# %% [markdown]
# Using the tuned SVC model, we had successfully reduced the false classes i.e. from 30 to only 8 EF classes falsely predicted as FF.

# %%
# Confusion matrix of test set
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# Comparing the present classification report to the previous report, we improved the F1-score of EF class from 46% to 69%, and small improvement of FF class from 62% to 68%.

# %%
# Classification report
y_pred = grid.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AF       0.48      0.70      0.57        20
#           EF       0.57      0.79      0.66        57
#           FF       0.75      0.58      0.65        76
#           GF       1.00      1.00      1.00        10
#           MF       0.33      0.29      0.31         7
#           NF       0.92      0.78      0.84        86
#
#     accuracy                           0.71       256
#    macro avg       0.67      0.69      0.67       256
# weighted avg       0.74      0.71      0.72       256

# %%
df=pd.DataFrame(data={'predictions': y_pred, 'actual': y_test})
df['result']=df['predictions']==df['actual']
df = df.reset_index().sort_values(by="index")
print(df.to_string())
# Out:
#      index predictions actual  result
# 177      2          AF     NF   False
# 127      5          NF     NF    True
# 168      7          NF     NF    True
# 139     10          NF     NF    True
# 56      23          EF     NF   False
# 146     29          NF     NF    True
# 43      30          NF     NF    True
# 100     31          NF     NF    True
# 99      33          NF     NF    True
# 38      39          NF     NF    True
# 243     44          NF     NF    True
# 90      49          NF     NF    True
# 128     54          AF     NF   False
# 206     55          NF     NF    True
# 218     60          NF     NF    True
# 75      63          AF     NF   False
# 79      65          AF     NF   False
# 0       66          NF     NF    True
# 20      67          AF     NF   False
# 240     69          NF     NF    True
# 245     70          NF     NF    True
# 108     72          NF     NF    True
# 104     76          NF     NF    True
# 109     77          NF     NF    True
# 81      78          NF     NF    True
# 193     79          NF     NF    True
# 151     81          NF     NF    True
# 253     82          NF     NF    True
# 138     84          NF     NF    True
# 65      86          NF     NF    True
# 233     90          FF     NF   False
# 66      96          NF     NF    True
# 132     97          FF     NF   False
# 172    101          MF     NF   False
# 71     109          EF     NF   False
# 60     110          NF     NF    True
# 143    118          FF     NF   False
# 91     120          NF     NF    True
# 242    131          AF     NF   False
# 202    133          NF     NF    True
# 252    135          NF     NF    True
# 70     136          NF     NF    True
# 94     137          NF     NF    True
# 46     139          NF     NF    True
# 194    148          NF     NF    True
# 170    155          NF     NF    True
# 239    158          NF     NF    True
# 255    164          NF     NF    True
# 254    165          AF     NF   False
# 40     168          NF     NF    True
# 114    174          NF     NF    True
# 235    181          NF     NF    True
# 178    192          AF     NF   False
# 58     196          NF     NF    True
# 2      198          NF     NF    True
# 219    199          NF     NF    True
# 212    204          NF     NF    True
# 45     208          NF     NF    True
# 72     209          NF     NF    True
# 57     210          NF     NF    True
# 166    211          NF     NF    True
# 3      212          NF     NF    True
# 36     213          NF     NF    True
# 126    215          AF     NF   False
# 196    218          AF     NF   False
# 62     227          EF     NF   False
# 164    231          NF     NF    True
# 107    235          NF     NF    True
# 251    239          NF     NF    True
# 131    244          NF     NF    True
# 105    247          NF     NF    True
# 145    250          NF     NF    True
# 204    254          NF     NF    True
# 167    259          NF     NF    True
# 52     260          NF     NF    True
# 95     265          NF     NF    True
# 163    266          NF     NF    True
# 22     275          NF     NF    True
# 6      280          NF     NF    True
# 169    281          NF     NF    True
# 113    286          NF     NF    True
# 124    290          AF     NF   False
# 69     292          NF     NF    True
# 117    294          NF     NF    True
# 7      296          NF     NF    True
# 93     299          FF     NF   False
# 82     300          GF     GF    True
# 149    302          GF     GF    True
# 215    306          MF     MF    True
# 201    309          NF     MF   False
# 14     311          AF     AF    True
# 13     314          MF     AF   False
# 241    319          MF     AF   False
# 165    323          AF     MF   False
# 28     326          NF     AF   False
# 78     328          AF     MF   False
# 186    331          EF     FF   False
# 216    332          AF     AF    True
# 150    333          AF     AF    True
# 231    334          AF     MF   False
# 44     338          MF     AF   False
# 123    344          FF     EF   False
# 85     346          FF     EF   False
# 249    351          EF     FF   False
# 199    352          FF     EF   False
# 141    355          EF     EF    True
# 198    361          AF     AF    True
# 144    362          AF     AF    True
# 157    363          AF     AF    True
# 8      365          AF     AF    True
# 103    367          EF     FF   False
# 191    368          FF     EF   False
# 130    375          AF     AF    True
# 118    381          AF     EF   False
# 142    382          EF     AF   False
# 61     383          EF     AF   False
# 153    388          AF     AF    True
# 195    393          AF     AF    True
# 248    398          AF     AF    True
# 112    409          EF     EF    True
# 18     411          EF     EF    True
# 32     412          EF     FF   False
# 129    422          EF     FF   False
# 54     424          EF     FF   False
# 217    425          EF     EF    True
# 203    428          EF     EF    True
# 223    429          EF     EF    True
# 175    430          EF     FF   False
# 211    432          EF     FF   False
# 181    433          EF     EF    True
# 1      434          EF     FF   False
# 246    436          EF     FF   False
# 41     439          NF     MF   False
# 97     440          MF     MF    True
# 16     442          EF     FF   False
# 176    444          EF     FF   False
# 224    445          EF     EF    True
# 160    447          FF     EF   False
# 48     449          EF     EF    True
# 190    450          EF     FF   False
# 87     451          EF     EF    True
# 236    456          EF     EF    True
# 162    457          GF     GF    True
# 179    462          EF     EF    True
# 135    464          FF     EF   False
# 42     467          EF     FF   False
# 31     468          EF     EF    True
# 106    477          FF     EF   False
# 50     479          EF     EF    True
# 119    481          EF     FF   False
# 183    485          EF     FF   False
# 189    493          FF     EF   False
# 226    494          FF     EF   False
# 180    497          EF     FF   False
# 237    500          EF     EF    True
# 187    501          EF     FF   False
# 207    507          EF     FF   False
# 63     513          EF     FF   False
# 37     514          EF     EF    True
# 158    516          EF     EF    True
# 30     519          EF     FF   False
# 15     522          EF     EF    True
# 205    523          EF     FF   False
# 209    525          EF     FF   False
# 34     526          EF     EF    True
# 174    530          EF     EF    True
# 154    537          EF     EF    True
# 68     541          GF     GF    True
# 111    542          GF     GF    True
# 5      543          GF     GF    True
# 185    544          GF     GF    True
# 88     547          FF     EF   False
# 155    551          EF     EF    True
# 133    552          EF     EF    True
# 76     557          EF     EF    True
# 21     558          EF     EF    True
# 92     559          EF     FF   False
# 188    569          EF     FF   False
# 17     575          EF     FF   False
# 89     576          EF     EF    True
# 222    581          EF     EF    True
# 214    582          EF     EF    True
# 49     586          EF     FF   False
# 213    587          EF     EF    True
# 33     588          EF     FF   False
# 244    596          EF     FF   False
# 51     597          FF     EF   False
# 225    601          EF     EF    True
# 192    603          EF     EF    True
# 230    615          EF     EF    True
# 121    623          EF     EF    True
# 86     628          EF     EF    True
# 29     629          EF     EF    True
# 152    630          EF     EF    True
# 122    631          EF     EF    True
# 228    633          EF     EF    True
# 11     635          EF     EF    True
# 220    638          EF     EF    True
# 208    643          EF     EF    True
# 125    644          EF     EF    True
# 4      652          FF     FF    True
# 64     653          FF     FF    True
# 83     657          FF     FF    True
# 73     660          NF     FF   False
# 140    664          EF     EF    True
# 120    666          EF     EF    True
# 55     667          EF     EF    True
# 27     675          FF     FF    True
# 200    677          NF     FF   False
# 9      679          FF     FF    True
# 115    680          FF     FF    True
# 161    684          NF     FF   False
# 221    685          FF     FF    True
# 84     689          FF     FF    True
# 74     691          FF     FF    True
# 101    696          FF     FF    True
# 12     703          FF     FF    True
# 250    707          FF     FF    True
# 10     708          FF     FF    True
# 147    709          FF     FF    True
# 102    712          FF     FF    True
# 35     718          FF     FF    True
# 59     732          FF     FF    True
# 210    738          FF     FF    True
# 110    739          FF     FF    True
# 238    744          FF     FF    True
# 53     745          FF     FF    True
# 148    751          FF     FF    True
# 67     752          FF     FF    True
# 156    756          FF     FF    True
# 23     757          FF     FF    True
# 229    759          FF     FF    True
# 182    761          FF     FF    True
# 39     766          FF     FF    True
# 232    767          FF     FF    True
# 26     768          FF     FF    True
# 159    770          FF     FF    True
# 98     777          FF     FF    True
# 171    786          FF     FF    True
# 24     787          FF     FF    True
# 173    788          FF     FF    True
# 227    791          FF     FF    True
# 184    795          FF     FF    True
# 197    799          FF     FF    True
# 234    800          FF     FF    True
# 25     801          FF     FF    True
# 247    806          FF     FF    True
# 80     807          FF     FF    True
# 134    816          FF     FF    True
# 136    817          FF     FF    True
# 137    828          GF     GF    True
# 47     829          GF     GF    True
# 19     839          GF     GF    True
# 96     848          AF     AF    True
# 77     849          AF     AF    True
# 116    851          AF     AF    True

# %%
X_train
# Out:
#      WEC: ava. Rotation  WEC: max. Rotation  WEC: min. Rotation  \
# 28                6.110               6.390               5.930
# 665               9.620              15.680               1.240
# 193               9.820              11.390               7.690
# 404              11.870              13.630              10.450
# 465              14.190              14.880              13.520
# ..                  ...                 ...                 ...
# 71               14.180              15.240              12.780
# 106               4.950               5.090               4.820
# 270              11.770              13.910              10.060
# 435               9.970              15.240               1.370
# 102               9.040               9.700               8.610
#
#      WEC: ava. Power  WEC: max. Power  WEC: min. Power  \
# 28                62               95               46
# 665             1708             3125                0
# 193              712             1162              199
# 404             1622             2621              975
# 465             3070             3152             2988
# ..               ...              ...              ...
# 71              2692             3117             1645
# 106                3               10                0
# 270             1602             2936              848
# 435             1762             3141                0
# 102              571              726              463
#
#      WEC: ava. Nacel position including cable twisting  \
# 28                                                 -58
# 665                                               -189
# 193                                               -154
# 404                                                111
# 465                                                196
# ..                                                 ...
# 71                                                 396
# 106                                               -241
# 270                                                619
# 435                                               -162
# 102                                               -445
#
#      WEC: ava. reactive Power  WEC: max. reactive Power  \
# 28                         41                        50
# 665                       168                      1012
# 193                        70                        91
# 404                        98                       156
# 465                       212                       217
# ..                        ...                       ...
# 71                        248                       288
# 106                        31                        59
# 270                       149                       259
# 435                       132                      1074
# 102                        69                        78
#
#      WEC: min. reactive Power  ...  Rectifier cabinet temp.  \
# 28                         40  ...                       27
# 665                         0  ...                       26
# 193                        46  ...                       29
# 404                        66  ...                       30
# 465                       209  ...                       34
# ..                        ...  ...                      ...
# 71                        162  ...                       24
# 106                        10  ...                       34
# 270                        90  ...                       25
# 435                         0  ...                       28
# 102                        54  ...                       29
#
#      Yaw inverter cabinet temp.  Fan inverter cabinet temp.  Ambient temp.  \
# 28                           20                          23              9
# 665                          24                          26             12
# 193                          20                          26              9
# 404                          32                          34             20
# 465                          30                          33             18
# ..                          ...                         ...            ...
# 71                           23                          25              9
# 106                          23                          29             10
# 270                          22                          25             11
# 435                          26                          28             15
# 102                          22                          27             11
#
#      Tower temp.  Control cabinet temp.  Transformer temp.  \
# 28            12                     22                 32
# 665           25                     35                 60
# 193           21                     29                 35
# 404           32                     39                 51
# 465           27                     38                 68
# ..           ...                    ...                ...
# 71            25                     33                 49
# 106            9                     18                 27
# 270           25                     33                 52
# 435           32                     43                 69
# 102           24                     33                 42
#
#      RTU: ava. Setpoint 1  Inverter averages  Inverter std dev
# 28                   3050             23.364             2.767
# 665                  3037             30.182             1.940
# 193                  3050             24.545             1.293
# 404                  3050             32.818             1.662
# 465                  3050             38.273             0.905
# ..                    ...                ...               ...
# 71                   3050             25.727             1.737
# 106                  3050             20.818             1.168
# 270                  3050             27.182             2.228
# 435                  3050             35.000             1.483
# 102                  3050             26.818             1.537
#
# [597 rows x 53 columns]

# %%
train_df.to_csv(r'C:\Users\MS214357006\Desktop\iiot-wind-turbine-analytics\train_df.csv')

# %% [markdown]
# With this improvement, however, there remains some issues recommended for **future improvements of this work**:
# * Eventhough there is improvement, 28 FF class still falsely predicted as EF
# * Score of MF and AF are very low: 28% and 43%

# %% [markdown]
# # 8. Conclusion

# %% [markdown]
# We analyzed data that comes from the Supervisory Control and Data Acquisition (SCADA) system of a wind turbine from April 2014 until April 2015, with the associated faults that occured during the operating times. The SCADA system gives more than 60 records of all components of the wind turbine such as nacelle, inverter, bearing, and so on. There were 5 fault modes that developed, labeled as FF, AF, EF, MF, and GF. We found out that the number of faults significantly increases in October 2014.
#
# During faulty times, there are anomalous behaviors of the wind turbine components. For example, during GF, the temperatures of all wind turbine components are lower than during normal conditions. However, temperatures during AF and EF are higher than normal. And then, the reactive power is anomalously high during EF, while power is lower during MF. Therefore, we could classify fault modes based on various SCADA measured components.
#
# We made an Adaptive Boosting (AdaBoost) based predictive model to classify fault modes. The data is largely imbalanced among fault modes, therefore SMOTE was implemented within a 5-fold CV pipeline. From that attempt, we achieved a macro F1 score of 64-65%. Two problematic classes, EF and FF, were falsely predicted. To correct this and improve the model performance, we performed hyperparameter tuning to tune 4 AdaBoost hyperparameters. After tuning, the macro F1 score improved to 69-70%. The number of false prediction of EF classes successfully reduces.
#
# The individual F1 scores of AF and MF were still low. Therefore, an improvement of this work is recommended and will be appreciated.
#
# **Thank you!**
